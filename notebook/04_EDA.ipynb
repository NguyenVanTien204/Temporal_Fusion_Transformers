# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import re

# %%
df = pd.read_csv(r'C:\Users\nguyen\OneDrive\Tài liệu\baitaplonn\Time_Series_with_Python\notebook\data\raw\sell_prices.csv')
df.head(10)
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26
# 5     CA_1  HOBBIES_1_001     11330        8.26
# 6     CA_1  HOBBIES_1_001     11331        8.26
# 7     CA_1  HOBBIES_1_001     11332        8.26
# 8     CA_1  HOBBIES_1_001     11333        8.26
# 9     CA_1  HOBBIES_1_001     11334        8.26

# %% [markdown]
# ```
# store_id: Mã cửa hàng bán sản phẩm (VD: CA_1, TX_2, WI_3)
# item_id: Mã sản phẩm (VD: HOBBIES_1_001, FOODS_3_012)
# wm_yr_wk: Mã tuần (week number) trong toàn bộ khoảng thời gian(1 số đầu là nguồn dữ liệu 2 số sau tương ứng năm, 2 số sau là số tuần của năm đó)
# sell_price: Giá bán trung bình của sản phẩm đó trong tuần (USD)
# ```

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6841121 entries, 0 to 6841120
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   store_id    object
#  1   item_id     object
#  2   wm_yr_wk    int64
#  3   sell_price  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 208.8+ MB
